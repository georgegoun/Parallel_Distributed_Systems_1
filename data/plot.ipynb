# %%
import matplotlib.pyplot as plt

threads=[1,2,3,4,6,8,16,32]
seconds_belgium_pthreads=[0.288594,0.145621,0.158770,0.133885,0.141146,0.131616,0.133248,0.128484]

seconds_belgium_opencilk=[0.228594,2.308159,1.784675,2.153292,2.440407,2.280025,2.669586,2.749384]

seconds_belgium_openmp=[0.288594,0.150775,0.160224,0.137133,0.152644,0.143747,0.136875,0.131713]

plt.plot(threads, seconds_belgium_pthreads, "r")
plt.plot(threads,seconds_belgium_opencilk, "b")
plt.plot(threads,seconds_belgium_openmp, "g")
plt.xlabel('Threads')
plt.ylabel('Seconds')
plt.title('Belgium')
plt.xticks(threads)
plt.show()

seconds_dblp_pthreads=[0.495455,0.322490,0.333303,0.313335,0.360712,0.325817,0.320789,0.327718]

seconds_dblp_opencilk=[0.495455,0.761039,0.830086,0.698455,0.823366,0.855515,0.856537,0.848713]

seconds_dblp_openmp=[0.495455,0.275034,0.354070,0.349468,2.265489,3.910468,4.671065,5.504930]

plt.plot(threads, seconds_dblp_pthreads, "r")
plt.plot(threads,seconds_dblp_opencilk, "b")
plt.plot(threads,seconds_dblp_openmp, "g")
plt.xlabel('Threads')
plt.ylabel('Seconds')
plt.title('DBLP')
plt.xticks(threads)
plt.show()

seconds_naca_pthreads=[0.672698,0.532365,0.484002,0.561462,0.561050,0.557973,0.505854,0.519652]

seconds_naca_opencilk=[0.672698,2.407892,1.995404,2.399811,2.170988,2.225673,2.153966,2.262110]

seconds_naca_openmp=[0.672698,0.545387,0.525822,0.456058,2.161220,3.673538,8.500938,21.352969]

plt.plot(threads, seconds_naca_pthreads, "r")
plt.plot(threads,seconds_naca_opencilk, "b")
plt.plot(threads,seconds_naca_openmp, "g")
plt.xlabel('Threads')
plt.ylabel('Seconds')
plt.title('NACA')
plt.xticks(threads)
plt.show()

seconds_youtube_pthreads=[8.845668,4.854925,4.812926,5.394094,5.248705,5.073084,5.843374,4.395901]

seconds_youtube_opencilk=[8.845668,5.640765,5.703775,5.854942,5.822997,5.911736,5.991317,6.282078]

seconds_youtube_openmp=[8.845668,5.279590,5.004996,5.010631,5.416406,5.889968,6.821911,7.362998]

plt.plot(threads, seconds_youtube_pthreads, "r")
plt.plot(threads,seconds_youtube_opencilk, "b")
plt.plot(threads,seconds_youtube_openmp, "g")
plt.xlabel('Threads')
plt.ylabel('Seconds')
plt.title('Youtube')
plt.xticks(threads)
plt.show()
